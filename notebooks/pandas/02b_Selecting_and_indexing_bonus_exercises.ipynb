# %%
import pandas as pd

# %% [markdown]
# Read the csv file from this url:
# 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
#
# Name it `sets_df`

# %%
url = 'https://drive.google.com/file/d/1P2EyVCFAPeJcQ_lAN2W-bjwtbizOeFXE/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
sets_df = pd.read_csv(path)

# %% [markdown]
# #### Exercise 1
# Select and display only the `"name"` and `"year"` columns from `sets_df` using `.loc`

# %%
sets_df.loc[:,['name','year']]
# Out:
#                                                   name  year
# 0                                         Wishing Well  2017
# 1    Advent Calendar 2011 Star Wars (Day  7) - Tool...  2011
# 2                                         Chief Wiggum  2014
# 3                                        Blaze Battler  1991
# 4                                 Dilophosaurus Ambush  2015
# ..                                                 ...   ...
# 995                      Basic Building Set Trial Size  1992
# 996                        Aquaman and Aqua Watercraft  2016
# 997                                      Mia's Bedroom  2012
# 998                              Inverted Slope Bricks  1987
# 999                                     Kingdoms Joust  2012
#
# [1000 rows x 2 columns]

# %% [markdown]
# #### Exercise 2
# Display the first 5 rows and first 3 columns of `sets_df` using `.iloc`

# %%
sets_df.iloc[:5,:3]
# Out:
#         set_num                                               name  year
# 0  TRUFRIENDS-1                                       Wishing Well  2017
# 1        7958-8  Advent Calendar 2011 Star Wars (Day  7) - Tool...  2011
# 2      71005-15                                       Chief Wiggum  2014
# 3        6593-1                                      Blaze Battler  1991
# 4       75916-1                               Dilophosaurus Ambush  2015

# %% [markdown]
# #### Exercise 3
# Set the `set_num` column as an index using `.set_index()`. Make sure the change is done on the original DataFrame.

# %%
sets_df = sets_df.set_index('set_num')
sets_df
# Out:
#               index                                               name  year  \
# set_num
# TRUFRIENDS-1      0                                       Wishing Well  2017
# 7958-8            1  Advent Calendar 2011 Star Wars (Day  7) - Tool...  2011
# 71005-15          2                                       Chief Wiggum  2014
# 6593-1            3                                      Blaze Battler  1991
# 75916-1           4                               Dilophosaurus Ambush  2015
# ...             ...                                                ...   ...
# 1668-1          995                      Basic Building Set Trial Size  1992
# 71237-1         996                        Aquaman and Aqua Watercraft  2016
# 3939-1          997                                      Mia's Bedroom  2012
# 5161-1          998                              Inverted Slope Bricks  1987
# 10223-1         999                                     Kingdoms Joust  2012
#
#               theme_id  num_parts
# set_num
# TRUFRIENDS-1       494         33
# 7958-8             225          9
# 71005-15           550          6
# 6593-1              74        126
# 75916-1            602        246
# ...                ...        ...
# 1668-1             469         30
# 71237-1            604         43
# 3939-1             494         86
# 5161-1             443         16
# 10223-1            196       1574
#
# [1000 rows x 5 columns]

# %% [markdown]
# #### Exercise 4
# Select the lego sets
# \['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11']

# %%
sets_df.loc[['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1067/2077705688.py in <cell line: 0>()
# ----> 1 sets_df.loc[['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1418                     raise ValueError("Cannot index with multidimensional key")
#    1419
# -> 1420                 return self._getitem_iterable(key, axis=axis)
#    1421
#    1422             # nested tuple slicing
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1358
#    1359         # A collection of keys
# -> 1360         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361         return self.obj._reindex_with_indexers(
#    1362             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1556         axis_name = self.obj._get_axis_name(axis)
#    1557
# -> 1558         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1559
#    1560         return keyarr, indexer
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11'], dtype='object')] are in the [index]"

# %% [markdown]
# #### Exercise 5
# Building on Exercise 4, select only the columns `"num_parts"` and `"theme_id"` for these sets.

# %%
sets_df.loc[['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11'],["num_parts",'theme_id']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1067/3877471564.py in <cell line: 0>()
# ----> 1 sets_df.loc[['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11'],["num_parts",'theme_id']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1373         # ugly hack for GH #836
#    1374         if self._multi_take_opportunity(tup):
# -> 1375             return self._multi_take(tup)
#    1376
#    1377         return self._getitem_tuple_same_dim(tup)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1325         # GH 836
#    1326         d = {
# -> 1327             axis: self._get_listlike_indexer(key, axis)
#    1328             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1329         }
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1556         axis_name = self.obj._get_axis_name(axis)
#    1557
# -> 1558         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1559
#    1560         return keyarr, indexer
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['2250-2', '7324-21', '9509-15', '2824-8', '7324-12', '60024-11'], dtype='object')] are in the [index]"

# %% [markdown]
# #### Exercise 6
# Reset the index so that `"num_set"` is just a regular column again.

# %%
sets_df = sets_df.reset_index()
sets_df
# Out:
#      index       set_num                                               name  \
# 0        0  TRUFRIENDS-1                                       Wishing Well
# 1        1        7958-8  Advent Calendar 2011 Star Wars (Day  7) - Tool...
# 2        2      71005-15                                       Chief Wiggum
# 3        3        6593-1                                      Blaze Battler
# 4        4       75916-1                               Dilophosaurus Ambush
# ..     ...           ...                                                ...
# 995    995        1668-1                      Basic Building Set Trial Size
# 996    996       71237-1                        Aquaman and Aqua Watercraft
# 997    997        3939-1                                      Mia's Bedroom
# 998    998        5161-1                              Inverted Slope Bricks
# 999    999       10223-1                                     Kingdoms Joust
#
#      year  theme_id  num_parts
# 0    2017       494         33
# 1    2011       225          9
# 2    2014       550          6
# 3    1991        74        126
# 4    2015       602        246
# ..    ...       ...        ...
# 995  1992       469         30
# 996  2016       604         43
# 997  2012       494         86
# 998  1987       443         16
# 999  2012       196       1574
#
# [1000 rows x 6 columns]

# %% [markdown]
# #### Exercise 7
# Now set `"year"` as the index and use `.loc` to select the year 1992. What happens?
# Reset the index after.

# %%
sets_df.set_index('year').loc[1992]
# Out:
#      set_num                                         name  theme_id  num_parts
# year
# 1992  1896-1                                  Trauma Team        78        296
# 1992   846-1                              Lighting Bricks       473         45
# 1992  1895-1                                   Sky Patrol        80         89
# 1992  9870-1  Pneumatic Rubber Bands and Pneumatic Tubing         1        144
# 1992  5274-1      8 Tires / Tyres (4x24, 4x 30 mm) w/hubs       453         16
# 1992  1769-1                                     Aircraft       466         23
# 1992  6405-1                               Sunset Stables        90        132
# 1992  9874-1                        Building Cards - 1090       532          5
# 1992  5304-1                                    Wheelsets       456          2
# 1992  1668-1                Basic Building Set Trial Size       469         30

# %%
sets_df.reset_index()
# Out:
#      index       set_num                                               name  \
# 0        0  TRUFRIENDS-1                                       Wishing Well
# 1        1        7958-8  Advent Calendar 2011 Star Wars (Day  7) - Tool...
# 2        2      71005-15                                       Chief Wiggum
# 3        3        6593-1                                      Blaze Battler
# 4        4       75916-1                               Dilophosaurus Ambush
# ..     ...           ...                                                ...
# 995    995        1668-1                      Basic Building Set Trial Size
# 996    996       71237-1                        Aquaman and Aqua Watercraft
# 997    997        3939-1                                      Mia's Bedroom
# 998    998        5161-1                              Inverted Slope Bricks
# 999    999       10223-1                                     Kingdoms Joust
#
#      year  theme_id  num_parts
# 0    2017       494         33
# 1    2011       225          9
# 2    2014       550          6
# 3    1991        74        126
# 4    2015       602        246
# ..    ...       ...        ...
# 995  1992       469         30
# 996  2016       604         43
# 997  2012       494         86
# 998  1987       443         16
# 999  2012       196       1574
#
# [1000 rows x 6 columns]

# %% [markdown]
# #### Exercise 8
# Use `set_index` to create a DataFrame with [two indexes](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html).

# %%
sets_df.set_index(['theme_id', 'set_num'])
# Out:
#                                                                     name  \
# theme_id set_num
# 494      TRUFRIENDS-1                                       Wishing Well
# 225      7958-8        Advent Calendar 2011 Star Wars (Day  7) - Tool...
# 550      71005-15                                           Chief Wiggum
# 74       6593-1                                            Blaze Battler
# 602      75916-1                                    Dilophosaurus Ambush
# ...                                                                  ...
# 469      1668-1                            Basic Building Set Trial Size
# 604      71237-1                             Aquaman and Aqua Watercraft
# 494      3939-1                                            Mia's Bedroom
# 443      5161-1                                    Inverted Slope Bricks
# 196      10223-1                                          Kingdoms Joust
#
#                        year  num_parts
# theme_id set_num
# 494      TRUFRIENDS-1  2017         33
# 225      7958-8        2011          9
# 550      71005-15      2014          6
# 74       6593-1        1991        126
# 602      75916-1       2015        246
# ...                     ...        ...
# 469      1668-1        1992         30
# 604      71237-1       2016         43
# 494      3939-1        2012         86
# 443      5161-1        1987         16
# 196      10223-1       2012       1574
#
# [1000 rows x 3 columns]

# %% [markdown]
# #### Exercise 9
# Display the columns `set_num`, `theme_id` and `num_parts` of the last 15 rows by using `.iloc`

# %%
# with .loc
#sets_df.loc[0:15,['set_num', 'theme_id', 'num_parts']]
#with iloc
sets_df.iloc[-15:,[0,-2,-1]]
# Out:
#      set_num  theme_id  num_parts
# 985   8803-0       538          0
# 986  71008-4       551          7
# 987   3829-1       317        724
# 988  30108-1       494         33
# 989  71001-7       545          7
# 990  41563-1       588         67
# 991   4478-2       167        153
# 992  65579-1       198          3
# 993   9491-1       165        133
# 994   7979-5       219          7
# 995   1668-1       469         30
# 996  71237-1       604         43
# 997   3939-1       494         86
# 998   5161-1       443         16
# 999  10223-1       196       1574
