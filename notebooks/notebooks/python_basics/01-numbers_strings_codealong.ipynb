# %% [markdown]
# Python has several built-in data types that are used to store different kinds of values. In this lesson, we'll cover the most commonly used data types in Python, including:
#
# 1.   Numbers
# 2.   Strings
# 3.   Booleans
# 4.   Lists
# 5.   Dictionaries
# 6.   Tuples
# 7.   Sets
#
# Let's dive in!

# %%
# your first python code
print("Hello world")

# print
# tpasdjh
# asfh
# Out:
# Hello world

# %% [markdown]
# ## Variables

# %% [markdown]
# We use variables to temporary store data in the computer's memory

# %%
# declare a variable
age = 21
# print(age)

# %%
print(age)
# Out:
# 21

# %%
age
# Out:
# 21

# %%
print(Age)

# %%
#see the difference
print("age")
# Out:
# age

# %%
# The variables can contain diferent type of data
price = 17.35 # Decimal number
first_name = "Sara" # String
is_online = True #Boolean. A boolean value can be true or false. Python is case sensitive
                #(see if you type true instead of True)

# %%
type(age)
# Out:
# int

# %%
print(age + 130)
# Out:
# 151

# %%
print(age)
# Out:
# 21

# %%
age = age + 10

# %%
age += 15
print(age)

# %%
age_after_10_years = age + 10

print(age_after_10_years)

# %% [markdown]
# To sum up, the three types of data in python are:
#
#
# 1.   Numbers
# 2.   Strings
# 3.   Booleans

# %%
10
"hey"
False

# %%
type(10)
# Out:
# int

# %%
type("hey")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1822790664.py in <cell line: 0>()
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %% [markdown]
# ## Numbers: Integers & floats

# %% [markdown]
# *   'int' (integers) - whole numbers, positive or negative, without decimals
# *   'float' (floating-point numbers) - real numbers, with decimal points

# %% [markdown]
# ### Arithmetic operators

# %%
x = 10
y = 3

print(x - y)
# print(x + y)
# print(x * y)
# print(x / y)
# print(x // y)
# print(x % y) #modulos operator
# print(x ** y)
# Out:
# 7

# %%
print(x + y)
print(x * y)
print(x / y)
print(x // y)
print(x % y) #modulos operator
print(x ** y)
# Out:
# 13
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# #### Augmented assigment operator

# %%
# x = x + 3
# is the same as x += 3

# %% [markdown]
# ### Comparisson operators

# %%
# boolean expressions - produces a boolean value
# x = 3 > 2
# x = 3 >= 2
# x = 3 < 2
# x = 3 <= 2
# x = 3 == 2 # Do not confuse "==" with "="
# x != 3

# %%
x = 3

# %%
print(x>2)
#print(x>=2)
#print(x<2)
#print(x<=2)
#print(x==2)
#print(x!=2)
# Out:
# True

# %% [markdown]
# The comparisson operators are very important, because quite often we have to compare values to evaluate certain conditions.

# %% [markdown]
# ### Logical operators

# %%
price = 75

# %%
price > 50
# Out:
# True

# %%
price < 50
# Out:
# False

# %%
price == 75
# Out:
# True

# %%
price == 71
# Out:
# False

# %%
price != 71
# Out:
# True

# %%
price = 75
print(price < 100 and price > 50)
# Out:
# True

# %%
print(price > 100 and price > 50)
# Out:
# False

# %%
price = 7
print(price > 50 or price > 5)
# Out:
# True

# %%
price = 7
print(not price > 50)
# Out:
# False

# %%
# The same concepts apply to floats
z = 9.5
type(z)
# Out:
# float

# %% [markdown]
# ### Type conversion

# %%
a = 10
b = "15"
c = a + b
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2878768814.py in <cell line: 0>()
#       1 a = 10
#       2 b = "15"
# ----> 3 c = a + b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
b
# Out:
# '15'

# %%
type(b)
# Out:
# str

# %%
int(b)
# Out:
# 15

# %%
type(int(b))
# Out:
# int

# %%
a = 10
b = "15"
c = a + int(b)
c
# Out:
# 25

# %%
a = 10
b = "15"
c = a + float(b)
c
# Out:
# 25.0

# %%
a = 10
b = "15"
c = str(a) + b
c
# Out:
# '1015'

# %%
# concatenation
x = "Timo"
y = "thy"

z = x + y

print(z)
# Out:
# Timothy

# %%
t = "Timo" + " " + "thy"
t
# Out:
# 'Timo thy'

# %%
x + " " + y
# Out:
# 'Timo thy'

# %% [markdown]
# ## Strings

# %%
wbs = "Data Science Course"

# %% [markdown]
# The string is an object and as such it has a bunch of capabilities. So if you type wbs. we can see all the capabilities available in a string object

# %%
wbs.

# %%
print(wbs.upper())
# Out:
# DATA SCIENCE COURSE

# %%
wbs

# %%
wbs_cap = wbs.upper()
wbs_cap
# Out:
# 'DATA SCIENCE COURSE'

# %%
wbs.find('D')
# Out:
# 0

# %%
wbs.find('d')
# Out:
# -1

# %%
wbs.find('a')
# Out:
# 1

# %%
wbs.find('S')
# Out:
# 5

# %%
wbs.find('s')
# Out:
# 17

# %%
# Data Science Course
# 012345

# %%
wbs[0]
# Out:
# 'D'

# %%
wbs[5]
# Out:
# 'S'

# %%
wbs[-1]
# Out:
# 'e'

# %%
wbs[-2]
# Out:
# 's'

# %%
# Return the index of a word
wbs.find('Course')
# Out:
# 13

# %%
wbs.find("C")
# Out:
# 13

# %%
print('Data' in wbs)
# Out:
# True

# %%
print('data' in wbs)
# Out:
# False

# %%
'Data' in wbs
# Out:
# True

# %%
wbs2 = wbs.replace("Course", "Bootcamp")

# %%
wbs2
# Out:
# 'Data Science Bootcamp'

# %%
wbs
# Out:
# 'Data Science Course'
