# %% [markdown]
# #intro to colab

# %% [markdown]
# ## intro to python

# %%
print("hello world")
# Out:
# hello world

# %%
print('hello world')
# Out:
# hello world

# %%
print('abc123')
# Out:
# abc123

# %% [markdown]
# ### printing numbers
